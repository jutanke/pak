# %% [markdown]
# # Cell Tracking Challenge
# http://www.celltrackingchallenge.net/datasets.html

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.insert(0,'../')
from pak import utils
from pak.datasets.CellTrackingChallenge import CellTrackingChallenge2D
import matplotlib.pyplot as plt

root = '/media/julian/Maxtor/DATA/pak/'
username = ''
pw = ''

ctc = CellTrackingChallenge2D(root, username, pw)

Imgs, Segs = ctc.get_train_all_segmented()
print(len(Imgs))


I = Imgs[13]; S = Segs[13]

fig = plt.figure(figsize=(16,16))
fig.add_subplot(221).imshow(I)
fig.add_subplot(222).imshow(S)

I = Imgs[55]; S = Segs[55]
fig.add_subplot(223).imshow(I)
fig.add_subplot(224).imshow(S)
plt.show()
# Out:
# 222
