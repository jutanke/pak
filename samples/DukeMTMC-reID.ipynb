# %% [markdown]
# # DukeMTMC-reID
#
# GitHub link: https://github.com/layumi/DukeMTMC-reID_evaluation

# %%
# %matplotlib inline

import sys
sys.path.insert(0,'../')
from pak.datasets.DukeMTMC import DukeMTMC_reID
from pak import utils
import matplotlib.pyplot as plt

root = '/home/julian/Data/pak_test1'

duke = DukeMTMC_reID(root)
X, Y = duke.get_train()

fig = plt.figure(figsize=(16,8))

count = 17

for i in range(count):
    ax = fig.add_subplot(2, count, i+1)
    ax.imshow(X[i])

X_test, Y_test = duke.get_test()

for i in range(count):
    ax = fig.add_subplot(2, count, count + i+1)
    ax.imshow(X_test[i])

plt.show()
# Out:
# unzip /home/julian/Data/pak_test1/DukeMTMC-reID.zip -> /home/julian/Data/pak_test1

# %% [markdown]
# | Position  | Name | Description |
# | ------------- | ------------- | ---------- |
# | 0  | Person Id  | >0: Person Id  |
# | 1  | camera  | camera id|
# | 2  | frame | frame nbr |
