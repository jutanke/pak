# %% [markdown]
# # CAD-120
# http://pr.cs.cornell.edu/humanactivities/data.php

# %%
# A = np.array([[1, 1, 1],
#            [2, 2, 2],
#            [5, 5, 5]])

# B = np.array([[0, 1, 0],
#            [1, 1, 0],
#            [1, 1, 1]])

# C = np.einsum('ij,jk->ik', A, B)

# %%
# c = C[2]
# _c = c[0]

# P @ _c

# %%
# C.shape

# D = np.einsum('ijk,kk->ijk', C, P)

# D

# %%
# P = np.eye(4) * 2

# %%
# A = np.ones((100, 15, 3))
# A[:, :, 0] = A[:, :, 0] * 0.1
# A[:, :, 1] = A[:, :, 1] * 0.2
# A[:, :, 2] = A[:, :, 2] * 0.3
# for i in range(100):
#     A[i, :, :] = A[i, :, :] + i

# B = np.ones((100, 15, 1))

# C = np.concatenate([A, B], axis=2)

# C

# %%
A = np.array([
    [
        [1, 2, 3],
        [4, 5, 6]
    ],
    [
        [10, 20, 30],
        [40, 50, 60]
    ],
    [
        [100, 200, 300],
        [400, 500, 600]
    ],
    [
        [1000, 2000, 3000],
        [4000, 5000, 6000]
    ]
    
], np.float64)

B = np.array([
    [1, 0, 0],
    [0, 0, -1],
    [0, 1, 0]
], np.float64)

C = np.einsum('ijk,lk', A, B)

print('A', A.shape)
print('C', C.shape)

C.astype('object')
# Out:
# A (4, 2, 3)
# C (4, 2, 3)
# array([[[1.0, -3.0, 2.0],
#         [4.0, -6.0, 5.0]],
#
#        [[10.0, -30.0, 20.0],
#         [40.0, -60.0, 50.0]],
#
#        [[100.0, -300.0, 200.0],
#         [400.0, -600.0, 500.0]],
#
#        [[1000.0, -3000.0, 2000.0],
#         [4000.0, -6000.0, 5000.0]]], dtype=object)

# %%
vec = A[0,0]

B @ vec
# Out:
# array([ 1., -3.,  2.])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import json; from pprint import pprint
Settings = json.load(open('settings.txt'))
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.insert(0,'../')
from os.path import isdir

root = Settings['data_root']

from pak.datasets.CAD_120 import CAD_120

data = CAD_120(root)

suj1 = data.get_subject(1)

# %%
vid = suj1['arranging_objects']['0510175431']

pts3d = data.get_3d_points_from_skel(vid['skeleton'])

person = pts3d[0]

# =========

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111, projection='3d')

data.plot(ax, person, plot_jids=True)

plt.axis('equal')
plt.show()
