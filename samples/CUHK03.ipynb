# %% [markdown]
# # CUHK03
# Original paper: https://www.cv-foundation.org/openaccess/content_cvpr_2014/papers/Li_DeepReID_Deep_Filter_2014_CVPR_paper.pdf
#
# The dataset has 3 subsets:
# * **labeled**: bounding boxes are labeled by humans
# * **detected**: bounding boxes are estimated by a pedestrian detector
# * **testsets**: contains the testing protocol

# %%
# %matplotlib inline
import json
from pprint import pprint
Settings = json.load(open('settings.txt'))
pprint(Settings)
print('')
import sys
sys.path.insert(0,'../')
from pak.datasets.CUHK03 import cuhk03 
from pak import utils
import matplotlib.pyplot as plt

root = Settings['data_root']
target_w, target_h = 64, 64

cuhk03 = cuhk03(root, target_w=target_w, target_h=target_h)


X, Y = cuhk03.get_labeled()

n = 6
fig = plt.figure(figsize=(16,8))
for i in range(n):
    fig.add_subplot(1, n, i+1).imshow(X[i+200])
plt.show()
# Out:
# {'data_root': '/storage/DATA/pak'}
# /home/julian/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# unzip /storage/DATA/pak/cuhk03_release.zip -> /storage/DATA/pak
# could not find memmaped /storage/DATA/pak/cuhk03_release/labeled64x64.npy
# cuhk03: view "labeled" 1/5
# cuhk03: view "labeled" 2/5
# cuhk03: view "labeled" 3/5
# cuhk03: view "labeled" 4/5
# cuhk03: view "labeled" 5/5
# write memmaped /storage/DATA/pak/cuhk03_release/labeled64x64.npy
# flush memmaped /storage/DATA/pak/cuhk03_release/labeled64x64.npy

# %% [markdown]
# ## Data shape

# %%
print(X.shape)
print(Y.shape)
# Out:
# (14097, 64, 64, 3)
# (14097,)

# %% [markdown]
# ## Dataset: detected

# %%
X, Y = cuhk03.get_detected()

print(X.shape)
print(Y.shape)

n = 6
fig = plt.figure(figsize=(16,8))
for i in range(n):
    fig.add_subplot(1, n, i+1).imshow(X[i+200])
plt.show()
# Out:
# could not find memmaped /storage/DATA/pak/cuhk03_release/detected64x64.npy
# cuhk03: view "detected" 1/5
# cuhk03: view "detected" 2/5
# cuhk03: view "detected" 3/5
# cuhk03: view "detected" 4/5
# cuhk03: view "detected" 5/5
# write memmaped /storage/DATA/pak/cuhk03_release/detected64x64.npy
# flush memmaped /storage/DATA/pak/cuhk03_release/detected64x64.npy
# (14097, 64, 64, 3)
# (14097,)
